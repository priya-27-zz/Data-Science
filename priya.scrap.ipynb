# %%
#import the library used to query a website
import urllib2

#specify the url
wiki = "https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_2018"

#Query the website and return the html to the variable 'page'
page = urllib2.urlopen(wiki)

#import the Beautiful soup functions to parse the data returned from the website
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(page)

# %%
print soup.prettify()
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of Bollywood films of 2018 - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
#   </script>
#   <script>
# ...

# %%
soup.title
# Out:
# <title>List of Bollywood films of 2018 - Wikipedia</title>

# %%
soup.title.string
# Out:
# u'List of Bollywood films of 2018 - Wikipedia'

# %%
soup.a
# Out:
# <a id="top"></a>

# %%
soup.find_all("a")
# Out:
# [<a id="top"></a>,
#  <a href="#mw-head">navigation</a>,
#  <a href="#p-search">search</a>,
#  <a href="/wiki/Bollywood" title="Bollywood">Bollywood Cinema</a>,
#  <a class="image" href="/wiki/File:Indiafilm.svg"><img alt="Indiafilm.svg" data-file-height="245" data-file-width="237" height="62" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1e/Indiafilm.svg/60px-Indiafilm.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1e/Indiafilm.svg/90px-Indiafilm.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/1e/Indiafilm.svg/120px-Indiafilm.svg.png 2x" width="60"/></a>,
#  <a class="mw-redirect" href="/wiki/List_of_Bollywood_films_of_the_1920s" title="List of Bollywood films of the 1920s">1920s</a>,
#  <a href="/wiki/List_of_Bollywood_films_of_1920" title="List of Bollywood films of 1920">1920</a>,
#  <a href="/wiki/List_of_Bollywood_films_of_1921" title="List of Bollywood films of 1921">1921</a>,
# ...

# %%
all_links=soup.find_all("a")
for link in all_links:
    print link.get("href")
# Out:
# None
# #mw-head
# #p-search
# /wiki/Bollywood
# /wiki/File:Indiafilm.svg
# /wiki/List_of_Bollywood_films_of_the_1920s
# /wiki/List_of_Bollywood_films_of_1920
# /wiki/List_of_Bollywood_films_of_1921
# /wiki/List_of_Bollywood_films_of_1922
# /wiki/List_of_Bollywood_films_of_1923
# /wiki/List_of_Bollywood_films_of_1924
# /wiki/List_of_Bollywood_films_of_1925
# /wiki/List_of_Bollywood_films_of_1926
# /wiki/List_of_Bollywood_films_of_1927
# /wiki/List_of_Bollywood_films_of_1928
# /wiki/List_of_Bollywood_films_of_1929
# /wiki/List_of_Bollywood_films_of_the_1930s
# /wiki/List_of_Bollywood_films_of_1930
# /wiki/List_of_Bollywood_films_of_1931
# /wiki/List_of_Bollywood_films_of_1932
# /wiki/List_of_Bollywood_films_of_1933
# /wiki/List_of_Bollywood_films_of_1934
# /wiki/List_of_Bollywood_films_of_1935
# /wiki/List_of_Bollywood_films_of_1936
# /wiki/List_of_Bollywood_films_of_1937
# /wiki/List_of_Bollywood_films_of_1938
# /wiki/List_of_Bollywood_films_of_1939
# ...

# %%
all_tables=soup.find_all('table')
all_tables
# Out:
# [<table class="vertical-navbox nowraplinks" style="float:right;clear:right;width:22.0em;margin:0 0 1.0em 1.0em;background:#f9f9f9;border:1px solid #aaa;padding:0.2em;border-spacing:0.4em 0;text-align:center;line-height:1.4em;font-size:88%;width: auto">\n<tr>\n<th class="navbox-title" style="padding:0.2em 0.4em 0.2em;font-size:145%;line-height:1.2em;font-size: 120%"><a href="/wiki/Bollywood" title="Bollywood">Bollywood Cinema</a></th>\n</tr>\n<tr>\n<td style="padding:0.2em 0 0.4em"><a class="image" href="/wiki/File:Indiafilm.svg"><img alt="Indiafilm.svg" data-file-height="245" data-file-width="237" height="62" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1e/Indiafilm.svg/60px-Indiafilm.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1e/Indiafilm.svg/90px-Indiafilm.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/1e/Indiafilm.svg/120px-Indiafilm.svg.png 2x" width="60"/></a></td>\n</tr>\n<tr>\n<th class="navbox-title" style="padding:0.1em;border-
# ...

# %%
right_table=soup.find('table', class_='wikitable sortable mw-collapsible')

# %%
right_table
# Out:
# <table class="wikitable sortable mw-collapsible">\n<tr style="background:#b0e0e6; text-align:center;">\n<th colspan="2" style="width:6%;"><b>Opening</b></th>\n<th style="width:18%;"><b>Title</b></th>\n<th style="width:10.5%;"><b>Director</b></th>\n<th style="width:30%;"><b>Cast</b></th>\n<th style="width:10%;"><b>Genre</b></th>\n<th>Production House</th>\n<th>Ref.</th>\n</tr>\n<tr>\n<td rowspan="5" style="text-align:center; background:plum;"><b>J<br/>\nU<br/>\nL</b></td>\n</tr>\n<tr>\n<td rowspan="1" style="text-align:center;background:#f1daf1;"><b>1</b></td>\n<td style="text-align:center;"><i><a href="/wiki/Firrkie" title="Firrkie">Firrkie</a></i></td>\n<td>Ankush Bhatt</td>\n<td><a href="/wiki/Karan_Singh_Grover" title="Karan Singh Grover">Karan Singh Grover</a>, <a href="/wiki/Karishma_Kotak" title="Karishma Kotak">Karishma Kotak</a>, <a href="/wiki/Neil_Nitin_Mukesh" title="Neil Nitin Mukesh">Neil Nitin Mukesh</a>, <a href="/wiki/Sandeepa_Dhar" title="Sandeepa Dhar">Sandeepa Dhar
# ...

# %%
A=[]
B=[]
C=[]
D=[]
E=[]
for row in right_table.findAll("tr"):
    cells = row.findAll('td')
    if len(cells)==5: #Only extract table body not heading
        A.append(cells[0].find(text=True))
        B.append(cells[1].find(text=True))
        C.append(cells[2].find(text=True))
        D.append(cells[3].find(text=True))
        E.append(cells[4].find(text=True))

# %%
#import pandas to convert list to data frame
import pandas as pd
df=pd.DataFrame(A,columns=['Movie Name'])
df['director']=B
df['Cast']=C
df['Genre']=D
df['Production House']=E

# %%
df
# Out:
#       Movie Name         director                              Cast  \
# 0         Genius      Anil Sharma  Utkarsh Sharma, Ishita Chauhan,
# 1         Paltan      J. P. Dutta                     Jackie Shroff
# 2  Arjun Patiala     Rohit Jugraj                    Diljit Dosanjh
# 3     Sui Dhaaga  Sharat Katariya                      Varun Dhawan
#
#         Genre              Production House
# 0        None  Soham Rockstar Entertainment
# 1  Action/War                   Zee Studios
# 2      Comedy                      T-Series
# 3     Romance                Yash Raj Films
